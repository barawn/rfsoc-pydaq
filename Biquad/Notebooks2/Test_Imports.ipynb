# %%
import sys, os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))


import importlib

print('Attempting imports')

print('\n')
print('Testing RFSoC_Daq')

import RFSoC_Daq
print(RFSoC_Daq.__class__)
print(RFSoC_Daq.__file__)

importlib.reload(RFSoC_Daq)
print(RFSoC_Daq.__class__)
print(RFSoC_Daq.__file__)

from RFSoC_Daq import RFSoC_Daq
print(type(RFSoC_Daq))
print(RFSoC_Daq.__class__)

print('\n')
print('Biquad')

import Biquad
print(Biquad.__class__)
print(Biquad.__file__)

importlib.reload(Biquad)
print(Biquad.__class__)
print(Biquad.__file__)

from Biquad import Biquad
print(type(Biquad))
print(Biquad.__class__)

print('\n')
print('SimBiquad')

import SimBiquad
print(SimBiquad.__class__)
print(SimBiquad.__file__)
sim_biquad_instance = SimBiquad.SimBiquad()
print(isinstance(sim_biquad_instance, SimBiquad.SimBiquad))

importlib.reload(SimBiquad)
print(SimBiquad.__class__)
print(SimBiquad.__file__)
sim_biquad_instance = SimBiquad.SimBiquad()
print(isinstance(sim_biquad_instance, SimBiquad.SimBiquad))

from SimBiquad import SimBiquad
print(type(SimBiquad))
print(SimBiquad.__class__)
print(SimBiquad.__bases__)


print('\n')
print('Biquad_Daq')

import Biquad_Daq
print(Biquad_Daq.__class__)
print(Biquad_Daq.__file__)

print(Biquad_Daq.__class__)
print(Biquad_Daq.__file__)

from Biquad_Daq import Biquad_Daq
print(type(Biquad_Daq))
print(Biquad_Daq.__class__)
print(Biquad_Daq.__bases__)


print('Import successful')
# Out:
# Attempting imports
#
#
# Testing RFSoC_Daq
# <class 'module'>
# /home/xilinx/rfsoc-pydaq/RFSoC_Daq.py
# <class 'module'>
# /home/xilinx/rfsoc-pydaq/RFSoC_Daq.py
# <class 'type'>
# <class 'type'>
#
#
# Biquad
# <class 'module'>
# /home/xilinx/rfsoc-pydaq/Biquad/Biquad.py
# <class 'module'>
# /home/xilinx/rfsoc-pydaq/Biquad/Biquad.py
# <class 'type'>
# <class 'type'>
#
#
# SimBiquad
# <class 'Biquad.Biquad'>
# <class 'module'>
# /home/xilinx/rfsoc-pydaq/Biquad/SimBiquad.py
# True
# <class 'Biquad.Biquad'>
# <class 'module'>
# /home/xilinx/rfsoc-pydaq/Biquad/SimBiquad.py
# True
# <class 'type'>
# <class 'type'>
# (<class 'Biquad.Biquad'>,)
#
#
# Biquad_Daq
# <class 'module'>
# /home/xilinx/rfsoc-pydaq/Biquad/Biquad_Daq.py
# <class 'module'>
# /home/xilinx/rfsoc-pydaq/Biquad/Biquad_Daq.py
# <class 'type'>
# <class 'type'>
# (<class 'RFSoC_Daq.RFSoC_Daq'>, <class 'Biquad.Biquad'>)
# Import successful
